# %%
import random
pachum=[]
Kim_Jong_um = ["2 Dias","3 Dias","5 Dias","No mk ya esta dañado","Esta medio medio pa","Lionel Andres Messi"]
class Banano():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="Telefono"
    self.color="amarillo"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=400*cantidad
    pachum.append(self.precio)
class manzana_roja():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="corazòn"
    self.color="rojo"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=800*cantidad
    pachum.append(self.precio)
class manzana_verde():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="corazòn"
    self.color="verde"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=500*cantidad
    pachum.append(self.precio)
class huevo():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="ovalado pa"
    self.color="piel"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=460*cantidad
    pachum.append(self.precio)
class melon():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="balòn"
    self.color="beige"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=3400*cantidad
    pachum.append(self.precio)
class durazno():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="culito"
    self.color="durazno"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1400*cantidad
    pachum.append(self.precio)
class zapote():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="esfèrico"
    self.color="verde"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1760*cantidad
    pachum.append(self.precio)
class limon():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="bola"
    self.color="verde"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=560*cantidad
    pachum.append(self.precio)
class fresa():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="dorito"
    self.color="rojita"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=950*cantidad
    pachum.append(self.precio)
class mango():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="mango"
    self.color="verde con tonalidades rojas o naranjas"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=3400*cantidad
    pachum.append(self.precio)
class naranja():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="circular"
    self.color="naranja xd"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=4620*cantidad
    pachum.append(self.precio)
class pepino():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="hmmm curioso un poco sus"
    self.color="verde"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=3800*cantidad
    pachum.append(self.precio)
class mangostino():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="redondo"
    self.color="morado con tonalidade rosas"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1700*cantidad
    pachum.append(self.precio)
class kiwi():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="bola con pelos"
    self.color="beige"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1760*cantidad
    pachum.append(self.precio)
class lechuga():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="cerebro"
    self.color="verde"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1950*cantidad
    pachum.append(self.precio)
class tomate():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="circular o algo extraño"
    self.color="rojo con tonalidades verdes"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=400*cantidad
    pachum.append(self.precio)
class papa():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="tuberculo"
    self.color="marròn"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=620*cantidad
    pachum.append(self.precio)
class maduro():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="telefono"
    self.color="amarillo"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1800*cantidad
    pachum.append(self.precio)
class mamon():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="redondo"
    self.color="verde"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1700*cantidad
    pachum.append(self.precio)
class genovesa():
  def __init__(self,cantidad):
    self.cantidad=cantidad
    self.forma="perfecta"
    self.color="hermosa"
    self.fecha_de_expiracion= random.choice(Kim_Jong_um)
    self.cantidad=cantidad
    self.precio=1000000*cantidad
    pachum.append(self.precio)

# %%
#Para ingresar los producto se debe esrcribir la letra "P" y su numero correspondiente a numero del producto
#P1 = Banano(2)
P1=Banano(1)
P1.__dict__
# Out:
# {'cantidad': 1,
#  'forma': 'Telefono',
#  'color': 'amarillo',
#  'fecha_de_expiracion': 'No mk ya esta dañado',
#  'precio': 400}
