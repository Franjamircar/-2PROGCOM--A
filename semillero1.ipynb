# %% [markdown]
# #Sistema de sincronía entre equipos de monitoreo de variables fisiológicas
#
# Línea: Programación, medicina, salud y estadística
#
# Grupo: SEBIUNAB
#
# proyecto: desarrollar un sistema de sincronización en equipos de monitoreo para la caracterización de variables fisiológicas mediante el software de MATLAB

# %% [markdown]
# #Evaluación del ruido ambiental en el campus de la UDES con un módulo electronico de bajo cosot con tiempo real.
#
#
# Línea: Calidad de aire y cambio climatico
#
#
# Grupo: GAIA (grupo ambiental de investigación aplicada)
#
# proyecto: trata de un aparato que mide el ruido ambiental en decibeles dependiendo en el lugar que lo coloquemos.

# %% [markdown]
# #industria 4.0 y economia ciscular  el en sector de servicios
#
# Línea:Reciclaje, sostenibilidad y economía
#
# grupo: SINERGÍA
#
# proyecto: establecer algunas estrategias para un desarrollo sostenible. Para tener en cuenta para las empresas del sector de servicios en Colombia, para la implementación de I4.0 y la ecoconomia circular.

# %% [markdown]
# #Expasión de celulas madre mesenquimales en condiciones hipóxicas en medio no xenógenico suplementado con plasma pobre en plaquetas.
#
# Línea:Medicina, Biología y salud
#
#  grupo: medicina regenerativa
#
#  proyecto: elaboración de cultivos in vintro con condiciones hipóxicas suplementado con plasma pobre en plaquetas (PPP) que permite la la expanción de las MSC, esto se aplicaria para en la medicina regenerativa

# %% [markdown]
# #Solución al problema al problema de ruteo de vehículos de flota heterogenea con transbordo lateral mediante metaheuristica de algoritmo genético.
#
# Línea: gestión  de cadenas de suministros y analitica de datos
#
# grupo: Opalo Research Group
#
# proyecto:

# %% [markdown]
# #Aplicación de técnicas de diagnóstico a un plasma generado a partir de fuego excitado por microondas

# %% [markdown]
# Línea:Energía nuclear, física e ingeniería
#
# Grupo: Energía Nuclear
#
# Proyecto: Estudiar algunos de los parámetros que caracteriza el plasma y crear una maquina o equipo capaz de generar ese tipo de plasma.

# %% [markdown]
# ![WhatsApp Image 2022-10-06 at 11.38.06 AM.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2022-10-06 at 11.59.41 AM.jpeg](data:image/jpeg;base64,...)
